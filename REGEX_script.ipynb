# %%
import pandas as pd
import numpy as np
import re
import os
from fuzzywuzzy import fuzz,process

# %%
pd.set_option('display.max_rows', 2000)
path = 'C:/Users/HP/Documents/DQ & Regex demo/'

# %%
client = pd.read_excel(os.path.join(path,'Inputs/client_data_week1.xlsx'))
employee_table = pd.read_excel(os.path.join(path,'Inputs/Employee Table.xlsx'))

# %%
employee_table
# Out:
#     SAP_ID         Employee names
# 0    16001            LEWIS, GABE
# 1    16002    SCOTT, MICHAEL GARY
# 2    16003     HALPERT, JAMES JIM
# 3    16004  BEESLY, PAMELA MORGAN
# 4    16005   SCHRUTE, DWIGHT KURT
# 5    16006   BERNARD, ANDY BAINES
# 6    16007     CALIFORNIA, ROBERT
# 7    16010        MALONE1, KEVIN
# 8    16011        MALONE2, KEVIN
# 9    16015       FLENDERSON, TOBY
# 10   16038         CORDRAY, DANNY
# 11   16041           SINGH, SADIQ
# 12   16042          BEESLY, HELEN
# 13   16039            NUGENT, BEN
# 14   16040                   A.J.

# %%
client
# Out:
#      CLIENT_ID                              CLIENT_NAME  \
# 0       220101                              DNNSV Group
# 1       220102                               Sportswear
# 2       220103                                 AGNIA UK
# 3       220104                                GGB Group
# 4       220105                                NikitasAE
# 5       220106                                  Nomitra
# 6       220107                                   ECWFMU
# 7       220108                                 PSS Gent
# 8       220109                                   Atotis
# 9       220110                              WorkHardLTD
# 10      220111                                    BALEM
# 11      220112                            BALEM Systems
# 12      220113                                  Bagadoo
# 13      220114                         Banking Wizzards
# 14      220115                                    BLASE
# 15      220116                           Green Wizzards
# 16      220117                          London TGI Firm
# 17      220118                                    DMOFA
# 18      220119                                  FGRDSVC
# 19      220120                                    CAFCA
# 20      220121         South East Plastic Hungary Firm
# 21      220122                    CASS Independent Firm
# 22      220123                           Fortress Trust
# 23      220124                                     GFSN
# 24      220125                                  DAFESUK
# 25      220126                                  Kentrik
# 26      220127                           AnalyticsQuick
# 27      220128                                   Bankie
# 28      220129                           Verity Clarity
# 29      220130                            Covid Maniacs
# 30      220131                               Secondment
# 31      220132                                Bank Suid
# 32      220133                                Doul Firm
# 33      220134                London Automotive Society
# 34      220135                  Berlin Business Society
# 35      220136                              Data Giants
# 36      220137                           FreeloanbankUK
# 37      220138                                    DraxT
# 38      220139                             CamTownTrust
# 39      220141                                   ECMGFF
# 40      220142                            Cube Exp Firm
# 41      220143                          Draco Euro Bank
# 42      220144                               Euromaster
# 43      220145                                Galconera
# 44      220146                     Generation Next Firm
# 45      220147                         FinanceFirmUKLTD
# 46      220148                           NET Gresp Firm
# 47      220149                             Gamian Group
# 48      220150                           CheaptradeLLP
# 49      220151                                  FurniDA
# 50      220152                               PorterPort
# 51      220153                Newest International Bank
# 52      220155                         New Data Talent
# 53      220156                           SKF Associates
# 54      220157                        Oldest Trust Bank
# 55      220158                                 EdinDLTD
# 56      220159                             BestTech4you
# 57      220160                               DFFFL bank
# 58      220161                                   Fadnof
# 59      220162                    Fadnof Finance Europe
# 60      220163                Fadnof Controls assurance
# 61      220164                                   IBLFUK
# 62      220165                              IMCBC Group
# 63      220166                            Schlaf Speed
# 64      220167                             Desten Group
# 65      220168                    Innovative Tech Firm
# 66      220169                             VATSAA Group
# 67      220170                                 Argonaft
# 68      220172                  DigTransfAssociates LLP
# 69      220173                             Crèmen Group
# 70      220174                   Corp Building Society
# 71      220175                                     PP&S
# 72      220176                                   Mavrex
# 73      220177                                   Mponex
# 74      220178                           MoneyWiseQuick
# 75      220179                            FullMoneyfirm
# 76      220180                            ToyStan Corp
# 77      220181                           BankAthletClub
# 78      220182                                 TrainOix
# 79      220183                       Goster VVBRG Group
# 80      220184                               IDMU Group
# 81      220185                               NewBankLTD
# 82      220186                 Cottage Building Society
# 83      220187                    Priv Building Society
# 84      220188                             Newport SLPV
# 85      220189                    NoMoreFreeFinance PLC
# 86      220190                                DPGS Firm
# 87      220191                              Ksilis Firm
# 88      220192                                GRP Folks
# 89      220193                          DeskFurn Credit
# 90      220194                                     PFG
# 91      220195                          TechQuality4you
# 92      220196                            TrainOix Bank
# 93      220197                 European Adelf Community
# 94      220198                              VinegarFree
# 95      220199                     Scandin Society Firm
# 96      220200                     DevelopersAtNoCharge
# 97      220201                   Navagio Trust Bank PLC
# 98      220202                              RFS BC Firm
# 99      220203                              PODgen Firm
# 100     220204                             HardBank LLP
# 101     220205                      LRTS Chartered Bank
# 102     220206                      Darl Estates Agents
# 103     220207                                      TBC
# 104     220208                          ABC Supermarket
# 105     220209                          The MasterYCube
# 106     220210                              PetLife PLC
# 107     220211                              Pencil Exps
# 108     220212               TM New Bank of Schweirlef
# 109     220213                    Bermen School of Arts
# 110     220214                        FlyingHighCharter
# 111     220215                    Turicum Private Bank
# 112     220216                        United Trust Bank
# 113     220217                     Unity Trust Bank PLC
# 114     220218                   Vanderber FinTech Bank
# 115     220219                            Various Tasks
# 116     220220                       Faurhhall Firm PLC
# 117     220221                        Guerilla Money Up
# 118     220222                        JetstreamBank LTD
# 119     220223                     WORMarmMort Bank Ltd
# 120     220224                           Snoler Bank UK
# 121     220225                             YouBuyYouWin
# 122     220226  FRBB Software International Association
# 123     220227                         IMUFG Securities
# 124     220228                                  CarFast
#
#             CLIENT_LOCATION  CLIENT_INDUSTRY  CLIENT_MANAGER_ID  \
# 0            UNITED KINGDOM         INTERNAL              16006
# 1                        UK           RETAIL              16010
# 2            UNITED KINGDOM          BANKING              16004
# 3                     SPAIN          BANKING              16010
# 4                  Austria           BANKING              16006
# 5                  Belgium   CAPITAL MARKETS              16003
# 6                    France          BANKING              16004
# 7                   Germany         PROPERTY              16006
# 8             Liechtenstein         INTERNAL              16038
# 9                Luxembourg          BANKING              16003
# 10                   Monaco          DEFENCE              16006
# 11             Netherlands           DEFENCE              16006
# 12              Switzerland  CAPITAL MARKETS              16003
# 13                 AUSTRIA           BANKING              16010
# 14                 BELGIUM           BANKING              16005
# 15                   FRANCE  CAPITAL MARKETS              16006
# 16                       UK       CONSULTING              16010
# 17                  Belarus          BANKING              16001
# 18                 Bulgaria           ENERGY              16006
# 19                  Czechia       CONSULTING              16004
# 20                  Hungary           RETAIL              16006
# 21                   Poland         INTERNAL              16005
# 22      Republic of Moldova  CAPITAL MARKETS              16006
# 23                  Romania  CAPITAL MARKETS              16006
# 24            UK Federation  CAPITAL MARKETS              16004
# 25                 Slovakia           ENERGY              16006
# 26                  Ukraine         INTERNAL              16002
# 27                   SWEDEN          BANKING              16007
# 28                  Denmark          BANKING              16006
# 29                  Estonia       GOVERNMENT              16002
# 30                  Finland         INTERNAL              16004
# 31                  Iceland          BANKING              16040
# 32                  Ireland         INTERNAL              16004
# 33           United Kingdom          BANKING              16006
# 34                Lithuania         PROPERTY              16005
# 35                   Norway         INTERNAL              16040
# 36           United Kingdom          BANKING              16001
# 37           United Kingdom           ENERGY              16006
# 38                  Albania           ENERGY              16005
# 39   Bosnia and Herzegovina           ENERGY              16038
# 40                  Croatia         INTERNAL              16038
# 41                   Greece          BANKING              16015
# 42                    Italy            MOTOR              16002
# 43                    Malta            MOTOR              16005
# 44               Montenegro     CONSTRUCTION              16006
# 45           UNITED KINGDOM          FINTECH              16006
# 46                 Portugal  CAPITAL MARKETS              16007
# 47               San Marino  CAPITAL MARKETS              16004
# 48                   Serbia  CAPITAL MARKETS              16006
# 49                 Slovenia          BANKING              16002
# 50                    Spain          BANKING              16007
# 51           United KINGDOM          BANKING              16003
# 52           United KINGDOM         INTERNAL              16040
# 53        UK; UNITED KINDOM           PHARMA              16006
# 54        UK; UNITED KINDOM          BANKING              16004
# 55        UK; UNITED KINDOM          BANKING              16010
# 56        UK; UNITED KINDOM       TECHNOLOGY              16006
# 57        UK; UNITED KINDOM          BANKING              16004
# 58        UK; UNITED KINDOM            MOTOR              16006
# 59        UK; UNITED KINDOM  CAPITAL MARKETS              16003
# 60        UK; UNITED KINDOM          BANKING              16039
# 61        UK; UNITED KINDOM  CAPITAL MARKETS              16015
# 62        UK; UNITED KINDOM          BANKING              16005
# 63        UK; UNITED KINDOM         INTERNAL              16039
# 64        UK; UNITED KINDOM         INTERNAL              16003
# 65        UK; UNITED KINDOM  CAPITAL MARKETS              16003
# 66        UK; UNITED KINDOM          BANKING              16003
# 67        UK; UNITED KINDOM           RETAIL              16003
# 68        UK; UNITED KINDOM         INTERNAL              16003
# 69        UK; UNITED KINDOM  CAPITAL MARKETS              16003
# 70        UK; UNITED KINDOM     CONSTRUCTION              16006
# 71        UK; UNITED KINDOM  CAPITAL MARKETS              16040
# 72        UK; UNITED KINDOM  CAPITAL MARKETS              16010
# 73        UK; UNITED KINDOM  CAPITAL MARKETS              16010
# 74        UK; UNITED KINDOM          FINTECH              16006
# 75        UK; UNITED KINDOM          FINTECH              16006
# 76        UK; UNITED KINDOM          BANKING              16007
# 77        UK; UNITED KINDOM          BANKING              16006
# 78        UK; UNITED KINDOM            MOTOR              16011
# 79        UK; UNITED KINDOM          BANKING              16001
# 80        UK; UNITED KINDOM          BANKING              16011
# 81        UK; UNITED KINDOM          BANKING              16011
# 82        UK; UNITED KINDOM     CONSTRUCTION              16007
# 83        UK; UNITED KINDOM     CONSTRUCTION              16006
# 84        UK; UNITED KINDOM       TECHNOLOGY              16005
# 85        UK; UNITED KINDOM  CAPITAL MARKETS              16004
# 86        UK; UNITED KINDOM  CAPITAL MARKETS              16006
# 87        UK; UNITED KINDOM         INTERNAL              16004
# 88        UK; UNITED KINDOM          TELECOM              16010
# 89        UK; UNITED KINDOM  CAPITAL MARKETS              16006
# 90        UK; UNITED KINDOM  CAPITAL MARKETS              16010
# 91        UK; UNITED KINDOM         INTERNAL              16040
# 92        UK; UNITED KINDOM          BANKING              16006
# 93        UK; UNITED KINDOM         INTERNAL              16040
# 94        UK; UNITED KINDOM          FINTECH              16006
# 95        UK; UNITED KINDOM         INTERNAL              16001
# 96        UK; UNITED KINDOM         INTERNAL              16041
# 97        UK; UNITED KINDOM          BANKING              16006
# 98        UK; UNITED KINDOM          BANKING              16040
# 99        UK; UNITED KINDOM          FINTECH              16003
# 100       UK; UNITED KINDOM          BANKING              16003
# 101       UK; UNITED KINDOM          BANKING              16001
# 102       UK; UNITED KINDOM         PROPERTY              16003
# 103       UK; UNITED KINDOM         INTERNAL              16004
# 104       UK; UNITED KINDOM           RETAIL              16010
# 105       UK; UNITED KINDOM         INTERNAL              16040
# 106       UK; UNITED KINDOM          BANKING              16006
# 107       UK; UNITED KINDOM          FINTECH              16006
# 108       UK; UNITED KINDOM          BANKING              16007
# 109       UK; UNITED KINDOM          FINTECH              16005
# 110       UK; UNITED KINDOM          FINTECH              16006
# 111       UK; UNITED KINDOM          BANKING              16007
# 112       UK; UNITED KINDOM          BANKING              16006
# 113       UK; UNITED KINDOM          BANKING              16006
# 114       UK; UNITED KINDOM          BANKING              16006
# 115       UK; UNITED KINDOM         INTERNAL              16005
# 116       UK; UNITED KINDOM            MOTOR              16005
# 117       UK; UNITED KINDOM          FINTECH              16006
# 118       UK; UNITED KINDOM          BANKING              16006
# 119       UK; UNITED KINDOM          BANKING              16005
# 120       UK; UNITED KINDOM          BANKING              16004
# 121       UK; UNITED KINDOM          FINTECH              16006
# 122       UK; UNITED KINDOM            MOTOR              16042
# 123       UK; UNITED KINDOM  CAPITAL MARKETS              16003
# 124       UK; UNITED KINDOM       CONSULTING              16004
#
#                                    CLIENT_MANAGER_NAME
# 0                                  Andy Baines Bernard
# 1                                       Malone 1,Kevin
# 2         pamela morgan beesly;  BEESLY, PAMELA MORGAN
# 3                                       Malone 1,Kevin
# 4                                  Andy Baines Bernard
# 5                      Halpert, James Jim (CO-MANAGER)
# 6                                 Pamela Morgan Beesly
# 7                                  Andy Baines Bernard
# 8                                        Danny Cordray
# 9                                    James Jim Halpert
# 10                                 Andy Baines Bernard
# 11                                 Andy Baines Bernard
# 12                                   James Jim Halpert
# 13                                      Malone1, Kevin
# 14   Schrute, Dwight Kurt (ASSISTANT TO THE REGIONA...
# 15                                 Andy Baines Bernard
# 16                                      Malone1, Kevin
# 17                    Gabe Lewis AND James Jim Halpert
# 18                                 Andy Baines Bernard
# 19                                Pamela Morgan Beesly
# 20                                 Andy Baines Bernard
# 21                                 Dwight Kurt Schrute
# 22                                 Andy Baines Bernard
# 23                                 Andy Baines Bernard
# 24        pamela morgan beesly;  BEESLY, PAMELA MORGAN
# 25                                 Andy Baines Bernard
# 26                                       Michael Scott
# 27                                   Robert California
# 28                                 Andy Baines Bernard
# 29                                       Michael Scott
# 30                                Pamela Morgan Beesly
# 31   Scott, Michael<michaelscott@dundermifflinanaly...
# 32        pamela morgan beesly;  BEESLY, PAMELA MORGAN
# 33                                 Andy Baines Bernard
# 34                                 Dwight Kurt Schrute
# 35                                       Michael Scott
# 36                                          Gabe Lewis
# 37                                 Andy Baines Bernard
# 38                                 Dwight Kurt Schrute
# 39                       Danny Cordray; Cordray, Danny
# 40                                       Danny Cordray
# 41                                    Flenderson, Toby
# 42                                       Michael Scott
# 43                                      Dwight Schrute
# 44                                 Andy Baines Bernard
# 45                                 Andy Baines Bernard
# 46               Robert California; California, Robert
# 47                                Pamela Morgan Beesly
# 48                                 Andy Baines Bernard
# 49                                       Michael Scott
# 50                                   Robert California
# 51                                   James Jim Halpert
# 52                                       Michael Scott
# 53                                 Andy Baines Bernard
# 54                                Pamela Morgan Beesly
# 55                                      Malone 1,Kevin
# 56                                 Andy Baines Bernard
# 57                                Pamela Morgan Beesly
# 58                                 Andy Baines Bernard
# 59                                   James Jim Halpert
# 60   Scott, Michael<michaelscott@dundermifflinanaly...
# 61                                    Flenderson, Toby
# 62                                      Dwight Schrute
# 63                                  Michael Gary Scott
# 64                                   James Jim Halpert
# 65                     Halpert, James Jim (CO-MANAGER)
# 66                                   James Jim Halpert
# 67                     Halpert, James Jim (CO-MANAGER)
# 68                                   James Jim Halpert
# 69                                   James Jim Halpert
# 70                                 Andy Baines Bernard
# 71                                  Michael Gary Scott
# 72                                      Malone 1,Kevin
# 73                                      Malone 1,Kevin
# 74                                 Andy Baines Bernard
# 75                                 Andy Baines Bernard
# 76                California,Robert; California,Robert
# 77                                 Andy Baines Bernard
# 78                                       Malone2,Kevin
# 79                                          Gabe Lewis
# 80                                       Malone2,Kevin
# 81                                       Malone2,Kevin
# 82                California,Robert; California,Robert
# 83                                 Andy Baines Bernard
# 84                                 Dwight Kurt Schrute
# 85        pamela morgan beesly;  BEESLY, PAMELA MORGAN
# 86                                 Andy Baines Bernard
# 87        pamela morgan beesly;  BEESLY, PAMELA MORGAN
# 88                                      Malone1, Kevin
# 89                                 Andy Baines Bernard
# 90                                      Malone1, Kevin
# 91                                  Michael Gary Scott
# 92                                 Andy Baines Bernard
# 93                                  Michael Gary Scott
# 94                                 Andy Baines Bernard
# 95                                          Gabe Lewis
# 96                                         Sadiq Singh
# 97                                 Andy Baines Bernard
# 98                                  Michael Gary Scott
# 99                     Halpert, James Jim (CO-MANAGER)
# 100                                  James Jim Halpert
# 101                                         Gabe Lewis
# 102                    Halpert, James Jim (CO-MANAGER)
# 103       pamela morgan beesly;  BEESLY, PAMELA MORGAN
# 104                                     Malone1, Kevin
# 105                                 Michael Gary Scott
# 106                                Andy Baines Bernard
# 107                                Andy Baines Bernard
# 108              Robert California; California, Robert
# 109                                Dwight Kurt Schrute
# 110                                Andy Baines Bernard
# 111               Robert California; California,Robert
# 112                                Andy Baines Bernard
# 113                                Andy Baines Bernard
# 114                                Andy Baines Bernard
# 115                                Dwight Kurt Schrute
# 116                                Dwight Kurt Schrute
# 117                                Andy Baines Bernard
# 118                                Andy Baines Bernard
# 119                                Dwight Kurt Schrute
# 120                               Pamela Morgan Beesly
# 121                                Andy Baines Bernard
# 122                           Beesly, Helen (on leave)
# 123                                  James Jim Halpert
# 124                               Pamela Morgan Beesly

# %% [markdown]
# ### Data Quality Check: We want to ensure that the employee names and the corresponding employee id have a 1:1 relationship. We want to see if the employee id is really a unique identifier.
#
# #### Are many people sharing 1 employee id?
# #### Are people assigned the wrong employee id?

# %%
# DQ Check 1:1 Mapping between employee id and manager name
client['ID_IS_UNIQUE'] = client.groupby(['CLIENT_MANAGER_ID'])['CLIENT_MANAGER_NAME'].transform(lambda x: x.nunique() == 1)
id_check = client.loc[client['ID_IS_UNIQUE'] == False, ['CLIENT_MANAGER_ID','CLIENT_MANAGER_NAME','ID_IS_UNIQUE']].sort_values(['CLIENT_MANAGER_ID'])

# %%
id_check.merge(employee_table, how = 'left', left_on = 'CLIENT_MANAGER_ID',right_on = 'SAP_ID')
# Out:
#     CLIENT_MANAGER_ID                                CLIENT_MANAGER_NAME  \
# 0               16001                                         Gabe Lewis
# 1               16001                                         Gabe Lewis
# 2               16001                                         Gabe Lewis
# 3               16001                   Gabe Lewis AND James Jim Halpert
# 4               16001                                         Gabe Lewis
# 5               16003                    Halpert, James Jim (CO-MANAGER)
# 6               16003                                  James Jim Halpert
# 7               16003                                  James Jim Halpert
# 8               16003                    Halpert, James Jim (CO-MANAGER)
# 9               16003                                  James Jim Halpert
# 10              16003                                  James Jim Halpert
# 11              16003                    Halpert, James Jim (CO-MANAGER)
# 12              16003                                  James Jim Halpert
# 13              16003                                  James Jim Halpert
# 14              16003                    Halpert, James Jim (CO-MANAGER)
# 15              16003                                  James Jim Halpert
# 16              16003                                  James Jim Halpert
# 17              16003                                  James Jim Halpert
# 18              16003                    Halpert, James Jim (CO-MANAGER)
# 19              16003                                  James Jim Halpert
# 20              16004                               Pamela Morgan Beesly
# 21              16004                               Pamela Morgan Beesly
# 22              16004       pamela morgan beesly;  BEESLY, PAMELA MORGAN
# 23              16004                               Pamela Morgan Beesly
# 24              16004       pamela morgan beesly;  BEESLY, PAMELA MORGAN
# 25              16004                               Pamela Morgan Beesly
# 26              16004       pamela morgan beesly;  BEESLY, PAMELA MORGAN
# 27              16004                               Pamela Morgan Beesly
# 28              16004                               Pamela Morgan Beesly
# 29              16004       pamela morgan beesly;  BEESLY, PAMELA MORGAN
# 30              16004                               Pamela Morgan Beesly
# 31              16004       pamela morgan beesly;  BEESLY, PAMELA MORGAN
# 32              16004       pamela morgan beesly;  BEESLY, PAMELA MORGAN
# 33              16004                               Pamela Morgan Beesly
# 34              16005                                Dwight Kurt Schrute
# 35              16005                                Dwight Kurt Schrute
# 36              16005                                Dwight Kurt Schrute
# 37              16005  Schrute, Dwight Kurt (ASSISTANT TO THE REGIONA...
# 38              16005                                     Dwight Schrute
# 39              16005                                     Dwight Schrute
# 40              16005                                Dwight Kurt Schrute
# 41              16005                                Dwight Kurt Schrute
# 42              16005                                Dwight Kurt Schrute
# 43              16005                                Dwight Kurt Schrute
# 44              16005                                Dwight Kurt Schrute
# 45              16007               California,Robert; California,Robert
# 46              16007               California,Robert; California,Robert
# 47              16007              Robert California; California, Robert
# 48              16007              Robert California; California, Robert
# 49              16007               Robert California; California,Robert
# 50              16007                                  Robert California
# 51              16007                                  Robert California
# 52              16010                                     Malone1, Kevin
# 53              16010                                     Malone1, Kevin
# 54              16010                                     Malone 1,Kevin
# 55              16010                                     Malone 1,Kevin
# 56              16010                                     Malone 1,Kevin
# 57              16010                                     Malone 1,Kevin
# 58              16010                                     Malone1, Kevin
# 59              16010                                     Malone1, Kevin
# 60              16010                                     Malone 1,Kevin
# 61              16010                                     Malone1, Kevin
# 62              16038                                      Danny Cordray
# 63              16038                                      Danny Cordray
# 64              16038                      Danny Cordray; Cordray, Danny
# 65              16039                                 Michael Gary Scott
# 66              16039  Scott, Michael<michaelscott@dundermifflinanaly...
# 67              16040                                      Michael Scott
# 68              16040                                      Michael Scott
# 69              16040  Scott, Michael<michaelscott@dundermifflinanaly...
# 70              16040                                 Michael Gary Scott
# 71              16040                                 Michael Gary Scott
# 72              16040                                 Michael Gary Scott
# 73              16040                                 Michael Gary Scott
# 74              16040                                 Michael Gary Scott
#
#     ID_IS_UNIQUE  SAP_ID         Employee names
# 0          False   16001            LEWIS, GABE
# 1          False   16001            LEWIS, GABE
# 2          False   16001            LEWIS, GABE
# 3          False   16001            LEWIS, GABE
# 4          False   16001            LEWIS, GABE
# 5          False   16003     HALPERT, JAMES JIM
# 6          False   16003     HALPERT, JAMES JIM
# 7          False   16003     HALPERT, JAMES JIM
# 8          False   16003     HALPERT, JAMES JIM
# 9          False   16003     HALPERT, JAMES JIM
# 10         False   16003     HALPERT, JAMES JIM
# 11         False   16003     HALPERT, JAMES JIM
# 12         False   16003     HALPERT, JAMES JIM
# 13         False   16003     HALPERT, JAMES JIM
# 14         False   16003     HALPERT, JAMES JIM
# 15         False   16003     HALPERT, JAMES JIM
# 16         False   16003     HALPERT, JAMES JIM
# 17         False   16003     HALPERT, JAMES JIM
# 18         False   16003     HALPERT, JAMES JIM
# 19         False   16003     HALPERT, JAMES JIM
# 20         False   16004  BEESLY, PAMELA MORGAN
# 21         False   16004  BEESLY, PAMELA MORGAN
# 22         False   16004  BEESLY, PAMELA MORGAN
# 23         False   16004  BEESLY, PAMELA MORGAN
# 24         False   16004  BEESLY, PAMELA MORGAN
# 25         False   16004  BEESLY, PAMELA MORGAN
# 26         False   16004  BEESLY, PAMELA MORGAN
# 27         False   16004  BEESLY, PAMELA MORGAN
# 28         False   16004  BEESLY, PAMELA MORGAN
# 29         False   16004  BEESLY, PAMELA MORGAN
# 30         False   16004  BEESLY, PAMELA MORGAN
# 31         False   16004  BEESLY, PAMELA MORGAN
# 32         False   16004  BEESLY, PAMELA MORGAN
# 33         False   16004  BEESLY, PAMELA MORGAN
# 34         False   16005   SCHRUTE, DWIGHT KURT
# 35         False   16005   SCHRUTE, DWIGHT KURT
# 36         False   16005   SCHRUTE, DWIGHT KURT
# 37         False   16005   SCHRUTE, DWIGHT KURT
# 38         False   16005   SCHRUTE, DWIGHT KURT
# 39         False   16005   SCHRUTE, DWIGHT KURT
# 40         False   16005   SCHRUTE, DWIGHT KURT
# 41         False   16005   SCHRUTE, DWIGHT KURT
# 42         False   16005   SCHRUTE, DWIGHT KURT
# 43         False   16005   SCHRUTE, DWIGHT KURT
# 44         False   16005   SCHRUTE, DWIGHT KURT
# 45         False   16007     CALIFORNIA, ROBERT
# 46         False   16007     CALIFORNIA, ROBERT
# 47         False   16007     CALIFORNIA, ROBERT
# 48         False   16007     CALIFORNIA, ROBERT
# 49         False   16007     CALIFORNIA, ROBERT
# 50         False   16007     CALIFORNIA, ROBERT
# 51         False   16007     CALIFORNIA, ROBERT
# 52         False   16010        MALONE1, KEVIN
# 53         False   16010        MALONE1, KEVIN
# 54         False   16010        MALONE1, KEVIN
# 55         False   16010        MALONE1, KEVIN
# 56         False   16010        MALONE1, KEVIN
# 57         False   16010        MALONE1, KEVIN
# 58         False   16010        MALONE1, KEVIN
# 59         False   16010        MALONE1, KEVIN
# 60         False   16010        MALONE1, KEVIN
# 61         False   16010        MALONE1, KEVIN
# 62         False   16038         CORDRAY, DANNY
# 63         False   16038         CORDRAY, DANNY
# 64         False   16038         CORDRAY, DANNY
# 65         False   16039            NUGENT, BEN
# 66         False   16039            NUGENT, BEN
# 67         False   16040                   A.J.
# 68         False   16040                   A.J.
# 69         False   16040                   A.J.
# 70         False   16040                   A.J.
# 71         False   16040                   A.J.
# 72         False   16040                   A.J.
# 73         False   16040                   A.J.
# 74         False   16040                   A.J.

# %% [markdown]
# ##### - Notice on rows 65 to 74, we find that Michael Scott has been assigned an employee id that is not his. It turns out that Ben Nugent and A.J. have left the company and Micheal has taken over their clientele.
#
# ##### - However due to bad file management nobody changed the employee id.
#
# #### Problem: Management have asked us to produce a dashboard showing the employee and the progress status of their engagements.
#
# ##### -  We could manually reassign these but if we had hundreds of cases like this, we would need to override the employee id based on the employee table.
# ##### -  The problem is that we need a unique identifier to do this. However if the unique id is corrupted then we can only rely on joining based on name column.
#
# ##### -  This is a horrible idea since employee names are not in the same format so joining the employee table based on employee name would never work.
#
# ### Q) So how can we produce our dashboard showing employees vs their engagement progress?
# ### Solution: We can massage the data using REGULAR EXPRESSION to standardise the naming formats improving dashboard quality which would make our stakeholders very happy as it reduces their work.

# %%
def name_cleaner(df,col,identifier):
    #ideal format: LASTNAME, FIRSTNAME or LASTNAME, FIRSTNAME MIDDLENAMES
    
    #case1: FIRSTNAME LASTNAME
    rows = df.shape[0]
    
    df['CLEANED_'+ str(col)] = df[col].str.upper()
    
    case1 = df.loc[df[col].str.contains(';|\s+AND+\s|,|/|\.|\?|@', regex = True) == False, [identifier, 'CLEANED_'+str(col)]]
    
    if case1.shape[0] != 0:
        case1['CASE1_CLEANED'] = np.where(case1['CLEANED_'+str(col)].str.count(' ') == 1,
                                         case1['CLEANED_'+str(col)].str.replace('^.+\s','', regex = True) + ', ' + case1['CLEANED_'+str(col)].str.replace('\s+[A-z]{2,}','',regex = True),
                                         case1['CLEANED_'+str(col)].str.replace('^.+\s','', regex = True) + ', ' + case1['CLEANED_'+str(col)].str.replace('\s+[A-z]+','', regex = True) + ' ' + case1['CLEANED_'+str(col)].replace('^\S+\s+|\s+\S+$','', regex = True))
        df = pd.merge(df,case1[[identifier,'CASE1_CLEANED']], how = 'left', on = identifier)
        df['CLEANED_'+ str(col)] = np.where(df['CASE1_CLEANED'].notnull() == True, df['CASE1_CLEANED'], df['CLEANED_'+str(col)])
                                         
    else:
        print('There are no FIRSTNAME LASTNAME patterns.')
        
    assert(df.shape[0] == rows, 'Duplication occured in case 1. Check')
    
    # CASE 2: lastname,Firstname (no space)
                                         
    case2 = df.loc[(df['CLEANED_'+str(col)].str.contains('\S+,+\S+', regex= True) == True) & (df['CLEANED_'+str(col)].str.contains(';') == False), [identifier, 'CLEANED_'+str(col)]]
    
    if case2.shape[0] != 0:
        case2['CASE2_CLEANED'] = case2['CLEANED_'+str(col)].str.replace(',',', ', regex = True)
        df = pd.merge(df,case2[[identifier,'CASE2_CLEANED']], how = 'left', on = identifier)
        df['CLEANED_'+ str(col)] = np.where(df['CASE2_CLEANED'].notnull() == True, df['CASE2_CLEANED'], df['CLEANED_'+str(col)])
    else:
        print('There are no Lastname,Firstname without space.')
        
    assert(df.shape[0] == rows, 'Duplication occured in case 2. Check')

    # CASE 3: contains AND or /
    case3 = df.loc[df['CLEANED_'+str(col)].str.contains('\s+AND+\s|\s*/+\s*|\S+/', regex = True) == True, [identifier, 'CLEANED_'+ str(col)]]
    
    if case3.shape[0] != 0:
        case3['CASE3_CLEANED'] = case3['CLEANED_'+str(col)].str.replace('\s+AND+\s|\s*/+\s*',';', regex = True)
        #case3['CASE3_CLEANED'] = case3['CASE3_CLEANED'].str.replace('; ',';')
        df = pd.merge(df,case3[[identifier,'CASE3_CLEANED']], how = 'left', on = identifier)
        df['CLEANED_'+ str(col)] = np.where(df['CASE3_CLEANED'].notnull() == True, df['CASE3_CLEANED'], df['CLEANED_'+str(col)])
    else:
        print('There are no AND or / cases.')
        
    assert(df.shape[0] == rows, 'Duplication occured in case 3. Check')
                    
    # CASE 4: brackets
    case4 = df.loc[df['CLEANED_'+str(col)].str.contains('\(\?|[A-z]+\)',regex= True) == True, [identifier, 'CLEANED_'+str(col)]]
    
    if case4.shape[0] != 0:
        case4['CASE4_CLEANED'] = case4['CLEANED_'+str(col)].str.replace('\(\?+\)','', regex = True)
        case4['CASE4_CLEANED'] = case4['CLEANED_'+str(col)].str.replace('\s*\(+[A-z]+\)','', regex = True)
        case4['CASE4_CLEANED'] = case4['CLEANED_'+str(col)].str.replace('\s*\(+[A-z]+.+\)','', regex = True)
                
        df = pd.merge(df,case4[[identifier,'CASE4_CLEANED']], how = 'left', on = identifier)
        df['CLEANED_'+ str(col)] = np.where(df['CASE4_CLEANED'].notnull() == True, df['CASE4_CLEANED'], df['CLEANED_'+str(col)])
    else:
        print('There are no bracket cases.')
    
    assert(df.shape[0] == rows, 'Duplication occured in case 4. Check')
    
    #  CASE 5: Numbers
    case5 = df.loc[(df['CLEANED_'+str(col)].str.contains('[0-9]', regex = True)) & (df['CLEANED_'+ str(col)].str.contains('\(', regex = True) == False), [identifier, 'CLEANED_'+str(col)]]
    
    if case5.shape[0] != 0:
        case5['CASE5_CLEANED'] = np.where(case5['CLEANED_'+str(col)].str.contains('[A-z]\s+[0-9]', regex = True),
        case5['CLEANED_'+str(col)].str.replace('(?<=\D)\s+(?=\d)','', regex = True),
        case5['CLEANED_'+str(col)])
                    
        df = pd.merge(df,case5[[identifier,'CASE5_CLEANED']], how = 'left', on = identifier)
        df['CLEANED_'+ str(col)] = np.where(df['CASE5_CLEANED'].notnull() == True, df['CASE5_CLEANED'], df['CLEANED_'+str(col)])
    else:
        print('There are no numbers in text.')
    
    assert(df.shape[0] == rows, 'Duplication occured in case 5. Check')
    
    # CASE 6: email addresses
    case6 = df.loc[df['CLEANED_'+str(col)].str.contains('<.+@.+>', regex = True), [identifier, 'CLEANED_'+str(col)]]
    
    if case6.shape[0] != 0:
        case6['CASE6_CLEANED'] = case6['CLEANED_'+str(col)].str.replace('<.+@.+>','', regex = True)
        df = pd.merge(df,case6[[identifier,'CASE6_CLEANED']], how = 'left', on = identifier)
        df['CLEANED_'+ str(col)] = np.where(df['CASE6_CLEANED'].notnull() == True, df['CASE6_CLEANED'], df['CLEANED_'+str(col)])
                    
    else:
        print('There are no email patterns.')
    
    assert(df.shape[0] == rows, 'Duplication occured in case 6. Check')
    
     # CASE 7: ; clean up
                    
    df['CLEANED_'+str(col)] = df['CLEANED_'+str(col)].str.replace('; ',';')
    case7 = df.loc[df['CLEANED_'+str(col)].str.contains('.*;.*', regex = True) == True, [identifier, 'CLEANED_'+str(col)]]
    if case7.shape[0] != 0:
        case7 = pd.concat([case7[identifier],case7['CLEANED_'+str(col)], case7['CLEANED_'+ str(col)].str.split(';',expand = True)],axis = 1)
        case7.reset_index(drop = True, inplace = True)
        
        def spacer(x):
            if x is not None:
                    if bool(re.search(' ',str(x)) == False):
                        return re.sub(',',', ',x)
                    elif bool(re.search('\S+,+\S+',str(x))) == True:
                        return re.sub(',',', ',x)
                    else:
                        return x
            else:
                return x
        columns = list(set(list(case7.columns)) - set([identifier,'CLEANED_'+str(col)]))
        
        for i in columns:
            case7[i] = case7[i].apply(spacer)
        
        # remove duplicates across rows
        dups = case7.apply(pd.Series.duplicated,axis = 1) #marks duplicates across rows true except the first
        case7 = case7.mask(dups, None)  #replaces the true values with None
        
        # merging the different columns together except nones
        case7['CASE7_CLEANED'] = case7[columns].apply(lambda x: ';'.join(x.dropna()), axis = 1)
        
        # joining cleaned column back to the dataset
        df = pd.merge(df, case7[[identifier,'CASE7_CLEANED']], how = 'left', on = identifier)
        df['CLEANED_'+str(col)] = np.where(df['CASE7_CLEANED'].notnull() == True,df['CASE7_CLEANED'],df['CLEANED_'+str(col)])
        
        assert(df.shape[0] == rows, 'Duplication occured in case 7. Check')
        #CASE 8: FIRSTNAME LASTNAME;LASTNAME, FIRSTNAME  --> LASTNAME, FIRSTNAME; LASTNAME, FIRSTNAME
                    
        case8 = case7.loc[(case7['CASE7_CLEANED'].str.contains('^[A-z]+(?!,)(?=\s)\s') == True)
                          & (case7['CASE7_CLEANED'].str.contains(';',regex = True) == True),[identifier, 'CLEANED_'+str(col), 'CASE7_CLEANED']]
        case8.reset_index(drop = True, inplace = True)
        case8 = pd.concat([case8[identifier],case8['CASE7_CLEANED'],case8['CASE7_CLEANED'].str.split(';',expand = True)], axis = 1)
        columns_case8 = list(set(list(case8.columns)) - set([identifier,'CLEANED_'+str(col),'CASE7_CLEANED']))
        case8[columns_case8] = case8[columns_case8].astype(str)
        
        for i in columns_case8:
            case8[i] = case8[i].str.lstrip()
            case8[i] = case8[i].str.rstrip()
        
        def standardiser(x):
            if x != None:
                if bool(re.search(',',str(x))) == False:
                    if len(re.findall(' ',str(x))) == 1:
                        return re.sub('^.+\s','',x) + ', ' + re.sub('\s+[A-z]{2,}','',x)
                    else:
                        return re.sub('^.+\s','',x) + ', ' + re.sub('\s+[A-z]{2,}','',x) + ' ' + re.sub('^\S+\s+|\s+\S+$','',x)
                else:
                    return x
            else:
                return x
                    
        for i in columns_case8:
            case8[i] = case8[i].apply(standardiser)
         # remove any duplicates: assign Nones to duplicates
        dups2 = case8.apply(pd.Series.duplicated, axis = 1)
        case8 = case8.mask(dups2, None)
        
        #remove any duplicates: (turn string nones into none)
        for i in columns_case8:
                    for j in range(case8.shape[0]):
                        if case8.loc[case8.index[j],i] == 'None':
                            case8.loc[case8.index[j],i] = None
        
        # remove any duplicates: Merge all columns except None:
        case8['CASE8_CLEANED'] = case8[columns_case8].apply(lambda x: ';'.join(x.dropna()), axis = 1)
        
        # joining to main dataset
        df = pd.merge(df,case8[[identifier,'CASE8_CLEANED']], how = 'left', on = identifier)
        df['CLEANED_'+ str(col)] = np.where(df['CASE8_CLEANED'].notnull() == True, df['CASE8_CLEANED'],df['CLEANED_'+ str(col)])
        
        assert(df.shape[0] == rows, 'Duplication occured in case 7. Check')
    else:
        print('There are no ; cases.')
    
        
    return df

# %%
client_clean = name_cleaner(client, 'CLIENT_MANAGER_NAME','CLIENT_ID')

# %% [markdown]
# ### Checking the unique employee names and if they satisfy are naming conventions.

# %%
client_clean['CLEANED_CLIENT_MANAGER_NAME'].drop_duplicates().to_frame().reset_index(drop = True)
# Out:
#        CLEANED_CLIENT_MANAGER_NAME
# 0             BERNARD, ANDY BAINES
# 1                   MALONE1, KEVIN
# 2            BEESLY, PAMELA MORGAN
# 3               HALPERT, JAMES JIM
# 4                   CORDRAY, DANNY
# 5             SCHRUTE, DWIGHT KURT
# 6   LEWIS, GABE;HALPERT, JAMES JIM
# 7                   SCOTT, MICHAEL
# 8               CALIFORNIA, ROBERT
# 9                      LEWIS, GABE
# 10                FLENDERSON, TOBY
# 11                 SCHRUTE, DWIGHT
# 12             SCOTT, MICHAEL GARY
# 13                  MALONE2, KEVIN
# 14                    SINGH, SADIQ
# 15                   BEESLY, HELEN

# %% [markdown]
# #### Notice that there are 2 names that we were unable to standardise through regular expression. These are SCOTT, MICHAEL GARY ad DWIGHTKURT, SCHRUTE.
#
# #### In one instance, an employee's middle name was included and in the other an employee's name was misspelt.
#
# #### Regular expression can only search and locate patterns, it cannot discover the similarities between names and override them. At a generalised code level, SCOTT, MICHAEL GARY and SCOTT, MICHEAL are two different people but we know that they are same.
#
# ### Q) How can we fix this issue?
#
# ### Solution: Fuzzy string matching via FuzzyWuzzy library.
#
# #### Fuzzy String Matching, also known as Approximate String Matching, is the process of finding strings that approximately match a pattern. The process has various applications such as spell-checking, DNA analysis and detection, spam detection, plagiarism detection e.t.c
#
# #### The Fuzzywuzzy library uses tein Distance to calculate the differences between sequences and patterns that was developed

# %%
unique_check2 = client_clean[['CLIENT_MANAGER_ID','CLEANED_CLIENT_MANAGER_NAME']].drop_duplicates().sort_values(['CLIENT_MANAGER_ID'])
unique_check2['IS_UNIQUE'] = unique_check2.groupby(['CLIENT_MANAGER_ID'])['CLEANED_CLIENT_MANAGER_NAME'].transform(lambda x: x.nunique() == 1)
unique_check2.loc[unique_check2['IS_UNIQUE'] == False,]
# Out:
#     CLIENT_MANAGER_ID     CLEANED_CLIENT_MANAGER_NAME  IS_UNIQUE
# 17              16001  LEWIS, GABE;HALPERT, JAMES JIM      False
# 36              16001                     LEWIS, GABE      False
# 14              16005            SCHRUTE, DWIGHT KURT      False
# 43              16005                 SCHRUTE, DWIGHT      False
# 60              16039                  SCOTT, MICHAEL      False
# 63              16039             SCOTT, MICHAEL GARY      False
# 31              16040                  SCOTT, MICHAEL      False
# 71              16040             SCOTT, MICHAEL GARY      False

# %% [markdown]
# ### The fuzz.ratio method simply scores based on the edit distance.
# ### The fuzz.partial_ratio matches with sub strings and then gives a score
# ### The token sort ratio method attempts to account for similar strings that are out of order.
# ### In our case the best metric would be token sort ratio as we have strings out of order and some missing string components.

# %%
def renamer(data,name,accuracy): 
        x = fuzz.token_sort_ratio(name,data)
        if x >= accuracy:
            output = name
        else:
            output = data
        return output

# %%
client_clean['CLEANED_CLIENT_MANAGER_NAME'] = client_clean['CLEANED_CLIENT_MANAGER_NAME'].apply(renamer,name = 'SCOTT, MICHAEL GARY',accuracy = 80)
client_clean['CLEANED_CLIENT_MANAGER_NAME'] = client_clean['CLEANED_CLIENT_MANAGER_NAME'].apply(renamer,name = 'SCHRUTE, DWIGHT KURT',accuracy = 80)
client_clean['CLEANED_CLIENT_MANAGER_NAME'].drop_duplicates().to_frame().reset_index(drop = True)
# Out:
#        CLEANED_CLIENT_MANAGER_NAME
# 0             BERNARD, ANDY BAINES
# 1                   MALONE1, KEVIN
# 2            BEESLY, PAMELA MORGAN
# 3               HALPERT, JAMES JIM
# 4                   CORDRAY, DANNY
# 5             SCHRUTE, DWIGHT KURT
# 6   LEWIS, GABE;HALPERT, JAMES JIM
# 7              SCOTT, MICHAEL GARY
# 8               CALIFORNIA, ROBERT
# 9                      LEWIS, GABE
# 10                FLENDERSON, TOBY
# 11                  MALONE2, KEVIN
# 12                    SINGH, SADIQ
# 13                   BEESLY, HELEN

# %%
## Check equality of expected number of distinct names vs actual number of distinct names

# %%
client_clean['CLEANED_CLIENT_MANAGER_NAME'].drop_duplicates().to_frame().reset_index(drop = True).shape[0] == employee_table.shape[0] -2 + 1
# Out:
# True

# %%
## Lets look at which names are still not unique based on employee id

# %%
unique_check3 = client_clean
unique_check3['IS_UNIQUE'] = unique_check3.groupby(['CLIENT_MANAGER_ID'])['CLEANED_CLIENT_MANAGER_NAME'].transform(lambda x: x.nunique() == 1)
unique_check3.loc[unique_check3['IS_UNIQUE'] == False, ['CLIENT_MANAGER_ID','CLEANED_CLIENT_MANAGER_NAME']]
# Out:
#      CLIENT_MANAGER_ID     CLEANED_CLIENT_MANAGER_NAME
# 17               16001  LEWIS, GABE;HALPERT, JAMES JIM
# 36               16001                     LEWIS, GABE
# 79               16001                     LEWIS, GABE
# 95               16001                     LEWIS, GABE
# 101              16001                     LEWIS, GABE

# %%
# Export data to inspect if needed

# %%
client_clean.to_excel(os.path.join(path,'week1_cleaned.xlsx'),index = False)
